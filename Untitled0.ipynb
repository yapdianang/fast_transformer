# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import os
os.chdir("/content/gdrive/My Drive/Colab Notebooks/fast_transformer")

# %%
# !ls transformer
# Out:
# batch.py	     flow.py		  multi_gpu_loss_compute.py
# batch.pyc	     flow.pyc		  multihead_attention.py
# decoder_layer.py     functional.py	  multihead_attention.pyc
# decoder_layer.pyc    functional.pyc	  my_iterator.py
# decoder.py	     generator.py	  noam_opt.py
# decoder.pyc	     generator.pyc	  noam_opt.pyc
# embeddings.py	     greedy.py		  pointerwise_feedforward.py
# embeddings.pyc	     greedy.pyc		  pointerwise_feedforward.pyc
# encoder_decoder.py   __init__.py	  positional_encoding.py
# encoder_decoder.pyc  __init__.pyc	  positional_encoding.pyc
# encoder_layer.py     label_smoothing.py   __pycache__
# encoder_layer.pyc    label_smoothing.pyc  sublayer_connection.py
# encoder.py	     layer_norm.py	  sublayer_connection.pyc
# encoder.pyc	     layer_norm.pyc

# %%
# !python 224_run.py
# Out:
# /usr/local/lib/python3.6/dist-packages/torch/nn/_reduction.py:49: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# /usr/local/lib/python3.6/dist-packages/torch/nn/parallel/_functions.py:61: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# Epoch step: 1 Loss 8.203745 Tokens per Sec: 165.108183
# Epoch step: 51 Loss 7.555438 Tokens per Sec: 351.919184
# Epoch step: 101 Loss 6.979842 Tokens per Sec: 277.479077
# Epoch step: 151 Loss 6.544046 Tokens per Sec: 321.963032
# Epoch step: 201 Loss 5.081192 Tokens per Sec: 286.989613
# Epoch step: 251 Loss 5.684173 Tokens per Sec: 335.359018
# Epoch step: 301 Loss 5.337075 Tokens per Sec: 303.656495
# Epoch step: 351 Loss 5.746422 Tokens per Sec: 257.403954
# ...

# %%
# !nvidia-smi
# Out:
# Tue Mar  5 18:02:50 2019
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 410.79       Driver Version: 410.79       CUDA Version: 10.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   29C    P8    28W / 149W |      0MiB / 11441MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# ...
